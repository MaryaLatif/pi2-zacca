# %%
import pandas as pd

file = '/Users/evaberry/Documents/ESILV A4/PI2/Dataset final/Updated_SENED_Budget_Solidarity_Syria-Turkey_2023_05_17_EN - NamesCoded.xlsx'

# %% [markdown]
# # Extraction of the data and export of it into dataframes

# %%
# First dataframe : line 1 to 31  
df1 = pd.read_excel(file, skiprows=0, nrows=31)

# Second dataframe : line 39 to 42 
df2 = pd.read_excel(file, skiprows=38, nrows=4)

# Third dataframe : line 48 to 54 
df3 = pd.read_excel(file, skiprows=47, nrows=7)

# Fourth dataframe : line 59 to 60 
df4 = pd.read_excel(file, skiprows=58, nrows=2)

# %% [markdown]
# # Dataframe 1 : Human resources

# %%
df1
# Out:
#    !!Please insert lines under the sub-headings if necessary!!  \
# 0          Name of the person in charge of the budget
# 1                           Name of the applicant NGO
# 2                                       Project title
# 3                                                 NaN
# 4                                                   1
# 5                                                 1.1
# 6                                                 NaN
# 7                                              1.1.01
# 8                                              1.1.02
# 9                                              1.1.03
# 10                                             1.1.04
# 11                                             1.1.05
# 12                                             1.1.06
# 13                                             1.1.07
# 14                                             1.1.08
# 15                                                NaN
# ...

# %% [markdown]
# In the df1 dataframe, we have new lines that appears because in reality those lines are hidden in the excel sheet. So, we need to understand why those values are hidden.

# %% [markdown]
# **Delete of the fourth first rows:**

# %%
df1 = df1.iloc[3:].reset_index(drop=True)
df1.columns = df1.iloc[0]      
df1 = df1[1:].reset_index(drop=True)

# %%
df1
# Out:
# 0      NaN Expenditure related to the project\nRecommendations       Unit  \
# 0        1           Human resources dedicated to the project         NaN
# 1      1.1              Salaries and employer's contributions         NaN
# 2      NaN                            Salary for coordination         NaN
# 3   1.1.01                      IT and Media Officer (50%) TR   per month
# 4   1.1.02                MHPSS Technical Specialist (10%) TR   per month
# 5   1.1.03                 Supply Chain Coordinator  (10%) TR   per month
# 6   1.1.04                       Project Coordinator (10%) TR   per month
# 7   1.1.05            Inclusion Technical Specialist (10%) SY   per month
# 8   1.1.06                          MEAL Coordinator (10%) TR   per month
# 9   1.1.07                            HR Coordinator (10%) TR   per month
# 10  1.1.08                       Finance Coordiantor (10%) TR   per month
# 11     NaN                       Salary for operational staff         NaN
# ...

# %% [markdown]
# # Dataframe 2 : Travel cost

# %%
df2
# Out:
#                            2  \
# 0                        2.1
# 1                        2.2
# 2                        2.3
# 3  Sub- total 2 Travel costs
#
#                                         Travel costs Unnamed: 2  Unnamed: 3  \
# 0             2 Cars  for mobile team and benfiaries  per month         2.0
# 1                                   Fuel for 2 cars   per month         5.0
# 2  Travel cost from Turkey to Syria for managemen...  per month         5.0
# 3                                                NaN        NaN         NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0      6000.0         NaN         NaN         0.0         NaN         NaN
# 1       200.0      1000.0         NaN         NaN         NaN         NaN
# 2       200.0         NaN         NaN         0.0         NaN         NaN
# 3         NaN      1000.0         NaN         0.0         0.0         0.0
#
# ...

# %% [markdown]
# # Dataframe 3 : Travel cost part two

# %%
df3
# Out:
#                                3.1.4             Water dispenser per item  \
# 0                              3.1.6     Supplies and Stationary  lumpsum
# 1                              3.1.7  Refreshment for activities  lumpsum
# 2                              3.1.8        PSS Kits for chilren  lumpsum
# 3                              3.1.9         PSS Kits for adults  lumpsum
# 4                             3.1.10     Printing MEAL materials  lumpsum
# 5                             3.1.11            Montessori tools  lumpsum
# 6  Sub-total 3 Material and supplies                         NaN      NaN
#
#      2          200    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0  1.0   400.000000    400.000000         NaN         NaN         NaN
# 1  1.0   400.000000    400.000000         NaN         NaN         NaN
# 2  1.0  7500.000000   7500.000000         NaN         NaN         NaN
# 3  1.0  7500.000000   7500.000000         NaN         NaN         NaN
# ...

# %% [markdown]
# # Dataframe 4 : other costs

# %%
df4
# Out:
#     4.3  Office running cost A'zaz with Mobile bills forproject staff   \
# 0   4.5                                                ECF
# 1   4.6                            Case management support
#
#          per month      6   183.333333   1100.0   Unnamed: 6   Unnamed: 7  \
# 0  per beneficiary  350.0         50.0    17500          NaN          NaN
# 1              NaN    NaN          NaN        0          NaN          NaN
#
#     Unnamed: 8   Unnamed: 9  ...   0.5   0.6   0.7   2163.910726        0.8  \
# 0          NaN          NaN  ...     0     0     0             0  89.342895
# 1          NaN          NaN  ...     0     0     0             0   0.000000
#
#    2227.365061     158.25127   4549.527058   4.135934  -3449.527058
# 0  3071.167874  15066.645051   18227.15582   1.041552    -727.15582
# 1     0.000000      0.000000       0.00000        NaN       0.00000
#
# [2 rows x 39 columns]
